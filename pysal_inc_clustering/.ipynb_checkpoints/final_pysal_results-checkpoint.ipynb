# %% [markdown]
# Taking instructions from the example found on http://darribas.org/gds15/labs/Lab_08.html, re: http://darribas.org/gds_scipy16/ipynb_md/07_spatial_clustering.html.

# %% [markdown]
# First I'll start by reading in the data. I think I'll just look at Chicago to begin with:

# %%
# importing recommended libraries

# %matplotlib inline

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pysal as ps
import geopandas as gpd
from sklearn import cluster
from sklearn.preprocessing import scale

sns.set(style="whitegrid")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %% [markdown]
# ## Chicago

# %%
chi_inc_geojson = '/Users/fionaedwardson/Documents/GitHub/GISIII_Final_Project/city_income_data/inc_data_geojson/chi/chi_inc.geojson'

# %% [raw]
# help(gpd.read_file)

# %%
chi_inc = gpd.read_file(chi_inc_geojson)
chi_inc.plot(color='red')

# %% [markdown]
# Nice! The CRS looks good too.

# %% [markdown]
# Now, let's follow the recommendation of the lab and plot the data as a univariate map.
#
# First I'll look at the data...

# %%
print(chi_inc)
# Out:
#      med_earn city_name                                           geometry
# 0     32321.0       chi  POLYGON ((-87.62433 41.74365, -87.62417 41.736...
# 1     34671.0       chi  POLYGON ((-87.59062 41.72952, -87.58871 41.726...
# 2     54606.0       chi  POLYGON ((-87.64060 41.95364, -87.64074 41.953...
# 3     62745.0       chi  POLYGON ((-87.64180 41.93498, -87.64139 41.934...
# 4     25571.0       chi  POLYGON ((-87.72286 41.78230, -87.72276 41.778...
# ..        ...       ...                                                ...
# 865   31359.0       chi  POLYGON ((-87.67790 41.74288, -87.67725 41.741...
# 866   50885.0       chi  POLYGON ((-87.80122 41.78476, -87.80122 41.784...
# 867   35464.0       chi  MULTIPOLYGON (((-87.68070 41.67726, -87.68070 ...
# 868   54734.0       chi  POLYGON ((-87.78201 41.79967, -87.78203 41.799...
# 869   43214.0       chi  POLYGON ((-87.77823 41.96853, -87.77283 41.968...
#
# [870 rows x 3 columns]

# %% [markdown]
# Working off of a tutorial from here: https://towardsdatascience.com/a-beginners-guide-to-create-a-cloropleth-map-in-python-using-geopandas-and-matplotlib-9cc4175ab630.

# %%
# pip install -U descartes

# %%
# viewing the data the proper way

chi_inc.head()
# Out:
#    med_earn city_name                                           geometry
# 0   32321.0       chi  POLYGON ((-87.62433 41.74365, -87.62417 41.736...
# 1   34671.0       chi  POLYGON ((-87.59062 41.72952, -87.58871 41.726...
# 2   54606.0       chi  POLYGON ((-87.64060 41.95364, -87.64074 41.953...
# 3   62745.0       chi  POLYGON ((-87.64180 41.93498, -87.64139 41.934...
# 4   25571.0       chi  POLYGON ((-87.72286 41.78230, -87.72276 41.778...

# %%
plt.rcParams['figure.figsize'] = [30, 10] #height, width
chi_inc.plot()

# %%
# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(30, 10))

ax.axis("off")

chi_inc.plot(column='med_earn', cmap='Blues', linewidth=0.8, ax=ax, edgecolor='0.8', legend=True)

# %%
type(chi_inc)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
chi_medearn = chi_inc['med_earn']

print(chi_medearn, type(chi_medearn))
# Out:
# 0      32321.0
# 1      34671.0
# 2      54606.0
# 3      62745.0
# 4      25571.0
#         ...
# 865    31359.0
# 866    50885.0
# 867    35464.0
# 868    54734.0
# 869    43214.0
# Name: med_earn, Length: 870, dtype: float64 <class 'pandas.core.series.Series'>

# %%
_ = sns.pairplot(chi_inc, kind='reg', diag_kind='kde')

# %% [markdown]
# Looking into the documentation https://seaborn.pydata.org/generated/seaborn.pairplot.html, as there's only one variable under consideration, the result is just a univariate plot. Let's move on to the actual clustering!

# %% [markdown]
# ## Kmeans clustering -- was unsuccessful
#
# I tried this with two separate models. If you'd like to see the setup of those models (and perhaps find where I went wrong?) see the inc_clustering_with_pysal file in the project repository.

# %% [markdown]
# ## new goals
#
# Based on resources I could find online, I think the following two goals are do-able:
#
# -

# %%
chi_inc
# Out:
#      med_earn city_name                                           geometry
# 0     32321.0       chi  POLYGON ((-87.62433 41.74365, -87.62417 41.736...
# 1     34671.0       chi  POLYGON ((-87.59062 41.72952, -87.58871 41.726...
# 2     54606.0       chi  POLYGON ((-87.64060 41.95364, -87.64074 41.953...
# 3     62745.0       chi  POLYGON ((-87.64180 41.93498, -87.64139 41.934...
# 4     25571.0       chi  POLYGON ((-87.72286 41.78230, -87.72276 41.778...
# ..        ...       ...                                                ...
# 865   31359.0       chi  POLYGON ((-87.67790 41.74288, -87.67725 41.741...
# 866   50885.0       chi  POLYGON ((-87.80122 41.78476, -87.80122 41.784...
# 867   35464.0       chi  MULTIPOLYGON (((-87.68070 41.67726, -87.68070 ...
# 868   54734.0       chi  POLYGON ((-87.78201 41.79967, -87.78203 41.799...
# 869   43214.0       chi  POLYGON ((-87.77823 41.96853, -87.77283 41.968...
#
# [870 rows x 3 columns]

# %% [markdown]
# **Max Income**

# %%
np.max(chi_inc['med_earn'])
# Out:
# 100508.0

# %%
chi_inc_max = chi_inc.loc[chi_inc['med_earn'] == 100508.0]

# %%
print(chi_inc_max, type(chi_inc_max))
# Out:
#      med_earn city_name                                           geometry
# 615  100508.0       chi  POLYGON ((-87.67824 41.93593, -87.67813 41.932... <class 'geopandas.geodataframe.GeoDataFrame'>

# %% [markdown]
# *Centroid*

# %%
chimax_geom = chi_inc_max["geometry"]

# %%
type(chimax_geom)
# Out:
# geopandas.geoseries.GeoSeries

# %%
chimax_geom.crs
# Out:
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: North America - onshore and offshore: Canada - Alberta; British Columbia; Manitoba; New Brunswick; Newfoundland and Labrador; Northwest Territories; Nova Scotia; Nunavut; Ontario; Prince Edward Island; Quebec; Saskatchewan; Yukon. Puerto Rico. United States (USA) - Alabama; Alaska; Arizona; Arkansas; California; Colorado; Connecticut; Delaware; Florida; Georgia; Hawaii; Idaho; Illinois; Indiana; Iowa; Kansas; Kentucky; Louisiana; Maine; Maryland; Massachusetts; Michigan; Minnesota; Mississippi; Missouri; Montana; Nebraska; Nevada; New Hampshire; New Jersey; New Mexico; New York; North Carolina; North Dakota; Ohio; Oklahoma; Oregon; Pennsylvania; Rhode Island; South Carolina; South Dakota; Tennessee; Texas; Utah; Vermont; Virginia; Washington; West Virginia; Wisconsin; Wyoming. US Virgin Islands. British Virgin Islands.
# - bounds: (167.65, 14.92, -47.74, 86.46)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %% [markdown]
# This is what we want it to be!

# %%
chimax_loc = chimax_geom.centroid
# Out:
# <ipython-input-31-0e75d5d82cdb>:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   chimax_loc = chimax_geom.centroid

# %% [markdown]
# **Min Income**

# %%
chimin = np.min(chi_inc['med_earn'])

# %%
chi_inc_min = chi_inc.loc[chi_inc['med_earn'] == chimin]

# %%
print(chi_inc_min, type(chi_inc_max))
# Out:
#      med_earn city_name                                           geometry
# 472    4292.0       chi  POLYGON ((-87.60604 41.78587, -87.60119 41.785... <class 'geopandas.geodataframe.GeoDataFrame'>

# %%
chimin_geom = chi_inc_min["geometry"]

# %%
chimin_loc = chimin_geom.centroid
# Out:
# <ipython-input-33-5f09d68d8f21>:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   chimin_loc = chimin_geom.centroid

# %%
chimin_loc
# Out:
# 472    POINT (-87.60128 41.79047)
# dtype: geometry

# %%
fig, gax = plt.subplots(figsize=(30,10))

# By only plotting rows in which the continent is 'South America' we only plot, well,
# South America.
world.query("continent == 'South America'").plot(ax = gax, edgecolor='black', color='white')

# This plot the cities. It's the same syntax, but we are plotting from a different GeoDataFrame.
# I want the cities as pale red dots.
gdf.plot(ax=gax, color='red', alpha = 0.5)

gax.set_xlabel('longitude')
gax.set_ylabel('latitude')
gax.set_title('South America')

gax.spines['top'].set_visible(False)
gax.spines['right'].set_visible(False)

plt.show()

# %%
# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(30, 10))

ax.axis("off")

chi_inc.plot(column='med_earn', cmap='Blues', linewidth=0.8, ax=ax, edgecolor='0.8', legend=True) 
chimin_loc.plot(ax=ax, color='black', alpha = 1)
chimax_loc.plot(ax=ax, color='white', alpha = 1)

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# Distance calculation. (Pulling in the function from: http://darribas.org/gds_scipy16/ipynb_md/01_data_processing.html)

# %%
from math import radians, sin, cos, sqrt, asin

def gcd(loc1, loc2, R=3961):
    """Great circle distance via Haversine formula

    Parameters
    ----------

    loc1: tuple (long, lat in decimal degrees)

    loc2: tuple (long, lat in decimal degrees)

    R: Radius of the earth (3961 miles, 6367 km)

    Returns
    -------
    great circle distance between loc1 and loc2 in units of R


    Notes
    ------
    Does not take into account non-spheroidal shape of the Earth



    >>> san_diego = -117.1611, 32.7157
    >>> austin = -97.7431, 30.2672
    >>> gcd(san_diego, austin)
    1155.474644164695


    """
    lon1, lat1 = loc1
    lon2, lat2 = loc2
    dLat = radians(lat2 - lat1)
    dLon = radians(lon2 - lon1)
    lat1 = radians(lat1)
    lat2 = radians(lat2)

    a = sin(dLat/2)**2 + cos(lat1)*cos(lat2)*sin(dLon/2)**2
    c = 2*asin(sqrt(a))

    return R * c

# %%
chimin_loc
# Out:
# 472    POINT (-87.60128 41.79047)
# dtype: geometry

# %%
chimax_loc
# Out:
# 615    POINT (-87.67587 41.93595)
# dtype: geometry

# %%
# ok, there's got to be a better way to do this, however:
cmin = [-87.60128, 41.79047]
cmax = [-87.67587, 41.93595]

# %%
gcd(cmin, cmax)
# Out:
# 10.765650737050473

# %% [markdown]
# So the distance between the tract with the highest income in Chicago, and the tract with the lowest income in Chicago, is about 11 miles.

# %% [markdown]
# ***Rinse and Repeat***
#
# ## San Diego

# %%
sd_inc_geojson = '/Users/fionaedwardson/Documents/GitHub/GISIII_Final_Project/city_income_data/inc_data_geojson/sd/sd_inc.geojson'

# %%
sd_inc = gpd.read_file(sd_inc_geojson)
sd_inc.plot(color='red')

# %% [markdown]
# Looks fine! Now looking at the data:

# %%
sd_inc.head()
# Out:
#    med_earn city_name                                           geometry
# 0   59821.0        sd  POLYGON ((-117.01063 32.86317, -117.01081 32.8...
# 1   31121.0        sd  POLYGON ((-116.54737 32.68717, -116.54921 32.6...
# 2   49331.0        sd  POLYGON ((-116.93192 32.64961, -116.93192 32.6...
# 3   44309.0        sd  POLYGON ((-116.93242 32.64889, -116.93240 32.6...
# 4   25578.0        sd  POLYGON ((-116.92684 32.61195, -116.92572 32.6...

# %%
# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(30, 30))

ax.axis("off")

sd_inc.plot(column='med_earn', cmap='Blues', linewidth=0.8, ax=ax, edgecolor='0.8', legend=True)

# %%
sd_medearn = sd_inc['med_earn']

sd_medearn.head()
# Out:
# 0    59821.0
# 1    31121.0
# 2    49331.0
# 3    44309.0
# 4    25578.0
# Name: med_earn, dtype: float64

# %%
_ = sns.pairplot(sd_inc, kind='reg', diag_kind='kde')

# %% [markdown]
# **Max Income**

# %%
sdmax = np.max(sd_inc['med_earn'])

# %%
sd_inc_max = sd_inc.loc[sd_inc['med_earn'] == sdmax]

# %% [markdown]
# *Centroid*

# %%
sdmax_geom = sd_inc_max["geometry"]

# %%
sdmax_geom.crs
# Out:
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: North America - onshore and offshore: Canada - Alberta; British Columbia; Manitoba; New Brunswick; Newfoundland and Labrador; Northwest Territories; Nova Scotia; Nunavut; Ontario; Prince Edward Island; Quebec; Saskatchewan; Yukon. Puerto Rico. United States (USA) - Alabama; Alaska; Arizona; Arkansas; California; Colorado; Connecticut; Delaware; Florida; Georgia; Hawaii; Idaho; Illinois; Indiana; Iowa; Kansas; Kentucky; Louisiana; Maine; Maryland; Massachusetts; Michigan; Minnesota; Mississippi; Missouri; Montana; Nebraska; Nevada; New Hampshire; New Jersey; New Mexico; New York; North Carolina; North Dakota; Ohio; Oklahoma; Oregon; Pennsylvania; Rhode Island; South Carolina; South Dakota; Tennessee; Texas; Utah; Vermont; Virginia; Washington; West Virginia; Wisconsin; Wyoming. US Virgin Islands. British Virgin Islands.
# - bounds: (167.65, 14.92, -47.74, 86.46)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
sdmax_loc = sdmax_geom.centroid
# Out:
# <ipython-input-182-edd3225e1b7a>:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   sdmax_loc = sdmax_geom.centroid

# %% [markdown]
# **Min Income**

# %%
sdmin = np.min(sd_inc['med_earn'])

# %%
print(sdmin)
# Out:
# 6682.0

# %%
sd_inc_min = sd_inc.loc[sd_inc['med_earn'] == sdmin]

# %%
sdmin_geom = sd_inc_min["geometry"]

# %%
sdmin_loc = sdmin_geom.centroid
# Out:
# <ipython-input-187-c6bd772c402e>:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   sdmin_loc = sdmin_geom.centroid

# %%
sdmax_loc
# Out:
# 260    POINT (-117.20616 32.96823)
# dtype: geometry

# %%
# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(30, 30))

ax.axis("off")

sd_inc.plot(column='med_earn', cmap='Blues', linewidth=0.8, ax=ax, edgecolor='0.8', legend=True) 
sdmin_loc.plot(ax=ax, color='black', alpha = 1, markersize = 70)
#maxloc.plot(ax=ax, color='white', alpha = 1)
sdmax_loc.plot(ax=ax, color='white', alpha = 1, markersize = 70)

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sdmin_loc
# Out:
# 34    POINT (-117.19818 32.77128)
# dtype: geometry

# %%
sdmax_loc
# Out:
# 260    POINT (-117.20616 32.96823)
# dtype: geometry

# %%
# ok, there's got to be a better way to do this, however:
smin = [-117.19818, 32.77128]
smax = [-117.20616, 32.96823]

# %%
gcd(smin, smax)
# Out:
# 13.623526249041635

# %% [markdown]
# So about 13 miles.

# %% [markdown]
# ***Last time...***
#
# ## Minneapolis

# %%
mpls_inc_geojson = '/Users/fionaedwardson/Documents/GitHub/GISIII_Final_Project/city_income_data/inc_data_geojson/mpls/mpls_inc.geojson'

# %%
mpls_inc = gpd.read_file(mpls_inc_geojson)
mpls_inc.plot(color='red')

# %% [markdown]
# Looks fine! Now looking at the data:

# %%
mpls_inc.head()
# Out:
#    med_earn city_name                                           geometry
# 0    8329.0      mpls  POLYGON ((-93.23930 44.98060, -93.23510 44.978...
# 1   72036.0      mpls  MULTIPOLYGON (((-93.31848 44.98699, -93.31847 ...
# 2   21441.0      mpls  POLYGON ((-93.29431 45.00954, -93.29420 45.005...
# 3   33382.0      mpls  POLYGON ((-93.25272 44.89071, -93.25290 44.890...
# 4   23625.0      mpls  POLYGON ((-93.29408 45.00261, -93.29409 44.999...

# %%
# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(30, 10))

ax.axis("off")

mpls_inc.plot(column='med_earn', cmap='Blues', linewidth=0.8, ax=ax, edgecolor='0.8', legend=True)

# %%
mpls_medearn = mpls_inc['med_earn']

mpls_medearn.head()
# Out:
# 0     8329.0
# 1    72036.0
# 2    21441.0
# 3    33382.0
# 4    23625.0
# Name: med_earn, dtype: float64

# %%
_ = sns.pairplot(mpls_inc, kind='reg', diag_kind='kde')

# %% [markdown]
# **Max Income**

# %%
mmax = np.max(mpls_inc['med_earn'])

# %%
mpls_inc_max = mpls_inc.loc[mpls_inc['med_earn'] == mmax]

# %% [markdown]
# *Centroid*

# %%
mplsmax_geom = mpls_inc_max["geometry"]

# %%
mplsmax_geom.crs
# Out:
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: North America - onshore and offshore: Canada - Alberta; British Columbia; Manitoba; New Brunswick; Newfoundland and Labrador; Northwest Territories; Nova Scotia; Nunavut; Ontario; Prince Edward Island; Quebec; Saskatchewan; Yukon. Puerto Rico. United States (USA) - Alabama; Alaska; Arizona; Arkansas; California; Colorado; Connecticut; Delaware; Florida; Georgia; Hawaii; Idaho; Illinois; Indiana; Iowa; Kansas; Kentucky; Louisiana; Maine; Maryland; Massachusetts; Michigan; Minnesota; Mississippi; Missouri; Montana; Nebraska; Nevada; New Hampshire; New Jersey; New Mexico; New York; North Carolina; North Dakota; Ohio; Oklahoma; Oregon; Pennsylvania; Rhode Island; South Carolina; South Dakota; Tennessee; Texas; Utah; Vermont; Virginia; Washington; West Virginia; Wisconsin; Wyoming. US Virgin Islands. British Virgin Islands.
# - bounds: (167.65, 14.92, -47.74, 86.46)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %% [markdown]
# This is what we want it to be!

# %%
mplsmax_loc = mplsmax_geom.centroid
# Out:
# <ipython-input-111-df63ade93804>:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   mplsmax_loc = mplsmax_geom.centroid

# %% [markdown]
# **Min Income**

# %%
mplsmin = np.min(mpls_inc['med_earn'])

# %%
print(mplsmin)
# Out:
# 5399.0

# %%
mpls_inc_min = mpls_inc.loc[mpls_inc['med_earn'] == mplsmin]

# %%
print(mpls_inc_min, type(mpls_inc_max))
# Out:
#      med_earn city_name                                           geometry
# 100    5399.0      mpls  POLYGON ((-93.24577 44.97210, -93.24567 44.970... <class 'geopandas.geodataframe.GeoDataFrame'>

# %%
mplsmin_geom = mpls_inc_min["geometry"]

# %%
mplsmin_loc = mplsmin_geom.centroid
# Out:
# <ipython-input-102-1280320e840f>:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   mplsmin_loc = mplsmin_geom.centroid

# %%
mplsmax_loc
# Out:
# 77    POINT (-93.32905 44.91394)
# dtype: geometry

# %% [markdown]
# Manually changing the location of the maximum because it's in a census tract that gets cut off by the city borders...

# %%
df = pd.DataFrame(
    {'Latitude': [44.91394],
     'Longitude': [-93.3245]})

# %%
point = [-93.32905, 44.91394]
maxloc = gpd.GeoDataFrame(
    df, geometry=gpd.points_from_xy(df.Longitude, df.Latitude))

# %%
mplsmin_loc
# Out:
# 100    POINT (-93.23055 44.97325)
# dtype: geometry

# %%
# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(30, 10))

ax.axis("off")

mpls_inc.plot(column='med_earn', cmap='Blues', linewidth=0.8, ax=ax, edgecolor='0.8', legend=True) 
mplsmin_loc.plot(ax=ax, color='black', alpha = 1)
maxloc.plot(ax=ax, color='white', alpha = 1)
#mplsmax_loc.plot(ax=ax, color='white', alpha = 1)

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
mplsmin_loc
# Out:
# 100    POINT (-93.23055 44.97325)
# dtype: geometry

# %%
maxloc
# Out:
#    Latitude  Longitude                    geometry
# 0  44.91394   -93.3245  POINT (-93.32450 44.91394)

# %%
# ok, there's got to be a better way to do this, however:
mmin = [-93.23055, 44.97325]
mmax = [-93.3245, 44.91394]

# %%
gcd(mmin, mmax)
# Out:
# 6.160036559586638

# %% [markdown]
# So about 6 miles.
